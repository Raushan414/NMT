# %%
import pandas as pd
import numpy as np

# %%
file = open('NMT_Dataset/parallel/IITB.en-hi.en', encoding="utf8")

# %%
for i in file:
    print(i)
    break;
# Out:
# Give your application an accessibility workout

# %%
import codecs

# %%
file = codecs.open('NMT_Dataset/parallel/IITB.en-hi.hi', encoding="utf8")

# %%
for i in file:
    print(i)
    break;
# Out:
# अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें

# %%
eng = codecs.open('NMT_Dataset/parallel/IITB.en-hi.en', encoding="utf8")
hin = codecs.open('NMT_Dataset/parallel/IITB.en-hi.hi', encoding="utf8")

# %%
en_list = []
hin_list = []

# %%
for i in eng:
    en_list.append(i)

# %%
for i in hin:
    hin_list.append(i)

# %%
df = pd.DataFrame({'english':en_list,'hindi':hin_list})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-630205331544> in <module>
# ----> 1 df = pd.DataFrame({'english':en_list,'hindi':hin_list})
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ...

# %%
len(en_list)
# Out:
# 1609684

# %%
len(hin_list)
# Out:
# 1610304

# %%
df = pd.read_csv('NMT_Dataset/Hindi_English_Truncated_Corpus.csv/Hindi_English_Truncated_Corpus.csv')

# %%
df.shape
# Out:
# (127607, 3)

# %%
df.head()
# Out:
#       source                                   english_sentence  \
# 0        ted  politicians do not have permission to do what ...
# 1        ted         I'd like to tell you about one such child,
# 2  indic2012  This percentage is even greater than the perce...
# 3        ted  what we really mean is that they're bad at not...
# 4  indic2012  .The ending portion of these Vedas is called U...
#
#                                       hindi_sentence
# 0  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 2   यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 3     हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते
# 4        इन्हीं वेदों का अंतिम भाग उपनिषद कहलाता है।

# %%
eng = codecs.open('NMT_Dataset/parallel/IITB.en-hi.en', encoding="utf8")
hin = codecs.open('NMT_Dataset/parallel/IITB.en-hi.hi', encoding="utf8")

# %%
en_list = []
hin_list = []

# %%
for i in eng:
    en_list.append(i)
print(len(en_list))
# Out:
# 1609684

# %%
for i in hin:
    hin_list.append(i)
print(len(hin_list))
# Out:
# 1610304

# %%
file = open('NMT_Dataset/final_dataset.txt','r',encoding='utf8')

# %%
temp = []
for i in file.split(','):
    temp.append(i)
    break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-15f8871c69b0> in <module>
#       1 temp = []
# ----> 2 for i in file.split(','):
#       3     temp.append(i)
#       4     break
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'split'

# %%
import ast

# %%
with open('NMT_Dataset/final_dataset.txt','r',encoding='utf8') as f:
    mylist = ast.literal_eval(f.read())

# %%
mylist[0]
# Out:
# ['fresh breath and shining teeth enhance your personality',
#  'ताजा साँसें और चमचमाते दाँत आपके व्यक्तित्व को निखारते हैं']

# %%
mylist
# Out:
# [['fresh breath and shining teeth enhance your personality',
#   'ताजा साँसें और चमचमाते दाँत आपके व्यक्तित्व को निखारते हैं'],
#  ['your selfconfidence also increases with teeth',
#   'दाँतों से आपका आत्मविश्वास भी बढ़ता है'],
#  ['bacteria stay between our gums and teeth',
#   'हमारे मसूढ़ों और दाँतों के बीच बैक्टीरिया मौजूद होते हैं'],
#  ['they make teeth dirty and breath stinky',
#   'ये दाँतों को गंदा और साँसों को बदबूदार बना देते हैं'],
#  ['you may keep your teeth clean and breath fresh by the help of some easy tips given here',
#   'यहाँ दिए कुछ आसान नुस्खों की मदद से आप अपने दाँतों को स्वच्छ और साँसों को ताजा रख सकते हैं'],
#  ['clean your teeth properly', 'दाँतों को ठीक से साफ करें'],
#  ['it takes two to three minutes to clean your teeth properly',
#   'दाँतों को ठीक से साफ करने में दो से तीन मिनट का समय लगता है'],
#  ['but most of the people give less than one minute for this',
#   'लेकिन ज्यादातर लोग इसके लिए एक मिनट से भी कम समय देते हैं'],
# ...

# %%
len(mylist)
# Out:
# 49999

# %%
mylist[0][0]
# Out:
# 'fresh breath and shining teeth enhance your personality'

# %%
file = open('NMT_Dataset/traing_english.txt','r',encoding='utf8')

# %%
cnt=0
for i in file:
    cnt=cnt+1
print(cnt)
# Out:
# 34924

# %%
file = open('NMT_Dataset/traing_hindi.txt','r',encoding='utf8')

# %%
cnt=0
for i in file:
    cnt=cnt+1
print(cnt)
# Out:
# 34924

# %%
mylist[-1]
# Out:
# ['somebody advised us that we should take safari for inside',
#  'हमें किसी ने सलाह दी कि आप अंदर के लिए सफारी ले लो']

# %%
mylist[34924]
# Out:
# ['animals like asian buffaloes leopards wild bears etc also reside here other than the rhinoceros',
#  'पोबितरा मुख्य रूप से एक सींग वाले गैंडे के लिए प्रसिद्ध है']

# %%
len(mylist)
# Out:
# 49999

# %%
file = open('NMT_Dataset/testing_hindi.txt','r',encoding='utf8')

# %%
cnt=0
for i in file:
    cnt=cnt+1
print(cnt)
# Out:
# 19960

# %%
file = open('NMT_Dataset/testing_english.txt','r',encoding='utf8')

# %%
cnt=0
for i in file:
    cnt=cnt+1
print(cnt)
# Out:
# 19960

# %%
19960+34924
# Out:
# 54884

# %%
complete it

# %%
file = open('NMT_Dataset/testing_english.txt','r',encoding='utf8')

# %%
for i in file:
    print(str(i))
    break
# Out:
# the place baidadih is famous for the big well

# %%
for l in mylist:
    if(l[0]=='complete it'):
        print(l)
# Out:
# ['complete it', 'आपकी आँखें अनमोल हैं इनकी रक्षा करें']
# ['complete it', 'हल्दी तुरई की जड़ आक के पत्ते सुरजने की जड़ इन सबको पीसकर पानी में घोलकर लेप बनाकर लगाने से बवासीर ठीक हो जाती है']
# ['complete it', 'भोजन से पूर्व पानी पीने पर जठराग्नि मंद हो जाती है']
# ['complete it', 'फलो का सेवन ना केवल आपके स्वास्थ्य के लिये अच्छा है बल्कि आपकी त्वचा के लिये भी अच्छा है']
# ['complete it', 'इंटरवल ट्रेनिंग जो लोग वजन घटाना और शरीर की क्षमता को बढ़ाना चाहते हैं उनके लिए इंटरवल ट्रेनिंग बेहतर विकल्प है']
# ['complete it', 'गर्भावस्था अधिकांश महिलाओं को खुशी उत्साह के साथ तनाव से भी भर देती है']
# ['complete it', 'आँव चिकना मल के साथ बारबार मल विसर्जन होना आमातिसार होता है']
# ['complete it', 'प्रौढ़ अवस्था के पुरुष लहसुन की कलियाँ शुद्ध घी में तल कर सुबह खाली पेट चबा कर या निगल कर लगातार सेवन करें तो यौन शक्ति की कमी दूर होती है और पौरुष बल में वृद्धि होती है']
# ...

# %%
eng_list = []
hin_list = []

# %%
file1 = open('NMT_Dataset/traing_english.txt','r',encoding='utf8')
file2 = open('NMT_Dataset/traing_hindi.txt','r',encoding='utf8')
file3 = open('NMT_Dataset/testing_english.txt','r',encoding='utf8')
file4 = open('NMT_Dataset/testing_hindi.txt','r',encoding='utf8')

# %%
for i in file1:
    eng_list.append(i)
    
for i in file3:
    eng_list.append(i)
    
for i in file2:
    hin_list.append(i)
    
for i in file4:
    hin_list.append(i)

# %%
len(eng_list)
# Out:
# 54884

# %%
len(hin_list)
# Out:
# 54884

# %%
df3 = pd.DataFrame({"English":eng_list,'Hindi':hin_list})

# %%
df2.head()
# Out:
#                                              English  \
# 0    dwarka is also a dhaam among the chaar dhaams\n
# 1  lord krishna had specially settled this amidst...
# 2  situated on the western railway s surendranaga...
# 3  this holy city is mathura the avatar land of l...
# 4  mathura station is on the northeastern railway...
#
#                                                Hindi
# 0               द्वारका चार धामों में एक धाम भी है\n
# 1  भगवान कृष्ण ने इसे समुद्र के बीच में विशेष रूप...
# 2  पश्चिम रेलवे की सुरेंद्रनगरओखा पोर्ट लाइन पर स...
# 3  यमुना तट पर भगवान श्रीकृष्ण की अवतार भूमि का य...
# 4  पूर्वोत्तर रेलवे की आगरा फोर्ट से गोरखपुर जाने...

# %%
df2.iloc[3]
# Out:
# English    this holy city is mathura the avatar land of l...
# Hindi      यमुना तट पर भगवान श्रीकृष्ण की अवतार भूमि का य...
# Name: 3, dtype: object

# %%
df2['English'][4]
# Out:
# 'mathura station is on the northeastern railway s line going to gorakhpur from agra fort and on the western railway s mumbaikotadelhi line\n'

# %%
df2['Hindi'][4]
# Out:
# 'पूर्वोत्तर रेलवे की आगरा फोर्ट से गोरखपुर जाने वाली लाइन तथा पश्चिम रेलवे की मुंबईकोटादिल्ली लाइन पर मथुरा स्टेशन है\n'

# %%
df = pd.read_csv('NMT_Dataset/Hindi_English_Truncated_Corpus.csv/Hindi_English_Truncated_Corpus.csv')

# %%
df3 = df[['english_sentence','hindi_sentence']]

# %%
df3.rename({'english_sentence':'English','hindi_sentence':'Hindi'},axis=1,inplace=True)
# Out:
# C:\Users\Raushan\Anaconda3\lib\site-packages\pandas\core\frame.py:4446: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df3
# Out:
#                                                   English  \
# 0       politicians do not have permission to do what ...
# 1              I'd like to tell you about one such child,
# 2       This percentage is even greater than the perce...
# 3       what we really mean is that they're bad at not...
# 4       .The ending portion of these Vedas is called U...
# ...                                                   ...
# 127602  Examples of art deco construction can be found...
# 127603                          and put it in our cheeks.
# 127604  As for the other derivatives of sulphur , the ...
# 127605  its complicated functioning is defined thus in...
# 127606  They've just won four government contracts to ...
#
#                                                     Hindi
# 0       राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 1       मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 2        यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# ...

# %%
df4 = pd.concat([df2,df3],axis=0)

# %%
df4.shape
# Out:
# (182491, 2)

# %%
file = open('NMT_Dataset/hin.txt',encoding='utf8')

# %%
for i in file:
    print(i)
    break
# Out:
# Help!	बचाओ!

# %%
import codecs

# %%
eng = codecs.open('NMT_Dataset/parallel/IITB.en-hi.en', encoding="utf8")
hin = codecs.open('NMT_Dataset/parallel/IITB.en-hi.hi', encoding="utf8")

# %%
cnt=0
for i in eng:
    cnt+=1
    if(cnt==1609684):
        print(i)
print(cnt)
# Out:
# It would also be broadcast on DD News.
# 1609684

# %%
cnt=0
for i in hin:
    cnt+=1
print(cnt)
# Out:
# 1610304

# %%
hin = codecs.open('NMT_Dataset/parallel/IITB.en-hi.hi', encoding="utf8")
for i in hin:
    print(i)
    break
# Out:
# अपने अनुप्रयोग को पहुंचनीयता व्यायाम का लाभ दें

# %%
import gzip

# %%
file = gzip.open('NMT_Dataset/HindEnCorp 0.5/hindencorp05.plaintext.gz','rb')
contents = file.read()

# %%
print(contents[1])
# Out:
# 105

# %%
for i in file:
    print(i)
    break

# %%
file = open('NMT_Dataset/HindEnCorp 0.5/hindencorp05.plaintext','rb')

# %%
for i in file:
    print(i)
    break
# Out:
# b'indic2012\t1-1\tmanual\tThis percentage is even greater than the percentage in India.\t\xe0\xa4\xaf\xe0\xa4\xb9 \xe0\xa4\xaa\xe0\xa5\x8d\xe0\xa4\xb0\xe0\xa4\xa4\xe0\xa4\xbf\xe0\xa4\xb6\xe0\xa4\xa4 \xe0\xa4\xad\xe0\xa4\xbe\xe0\xa4\xb0\xe0\xa4\xa4 \xe0\xa4\xae\xe0\xa5\x87\xe0\xa4\x82 \xe0\xa4\xb9\xe0\xa4\xbf\xe0\xa4\xa8\xe0\xa5\x8d\xe0\xa4\xa6\xe0\xa5\x81\xe0\xa4\x93\xe0\xa4\x82 \xe0\xa4\xaa\xe0\xa5\x8d\xe0\xa4\xb0\xe0\xa4\xa4\xe0\xa4\xbf\xe0\xa4\xb6\xe0\xa4\xa4 \xe0\xa4\xb8\xe0\xa5\x87 \xe0\xa4\x85\xe0\xa4\xa7\xe0\xa4\xbf\xe0\xa4\x95 \xe0\xa4\xb9\xe0\xa5\x88\xe0\xa5\xa4\n'

# %%
file = open('NMT_Dataset/HindEnCorp 0.5/hindencorp05.export','r',encoding='utf8')

# %%
for i in file:
    print(i)
    break
# Out:
# wikiner2013inflected	1-1	1.000	Sharaabi|Sharaabi|NNP	शराबी|शराबी.0|NN.n.m.sg.3.d

# %%
file = open('NMT_Dataset/HindEnCorp 0.5/hindencorp05.plaintext','r',encoding='utf8')

# %%
cnt=0
for i in file:
    cnt+=1
print(cnt)
# Out:
# 273885

# %%
file = open('NMT_Dataset/HindEnCorp 0.5/hindencorp05.export','r',encoding='utf8')

# %%
cnt=0
for i in file:
    cnt+=1
    
print(cnt)
# Out:
# 273885

# %%
content = file.read()

# %%
content[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-ee911ccdf81e> in <module>
# ----> 1 content[0]
#
# IndexError: string index out of range

# %%
import pandas as pd

# %%
df = pd.read_excel('NMT_Dataset/Book1.xlsx',header=None)

# %%
df.head()
# Out:
#                       0          1       2  \
# 0  wikiner2013inflected 2021-01-01       1
# 1                   ted 2021-01-01       1
# 2                   ted 2021-01-01       1
# 3             indic2012 2021-01-01  manual
# 4            quote-name 2021-01-01       1
#
#                                                    3  \
# 0                                           Sharaabi
# 1  politicians do not have permission to do what ...
# 2         I'd like to tell you about one such child,
# 3  This percentage is even greater than the perce...
# 4                                                NaN
#
#                                                    4
# 0                                              शराबी
# 1  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 2  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 3   यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 4                                                NaN

# %%
df.isna().sum()
# Out:
# 0       0
# 1       0
# 2       0
# 3    1016
# 4    1053
# dtype: int64

# %%
df.shape
# Out:
# (273885, 5)

# %%
df2 = df.dropna()

# %%
df2.isna().sum()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %%
df2.shape
# Out:
# (272753, 5)

# %%
df2 = df2[[3,4]]

# %%
df2
# Out:
#                                                         3  \
# 0                                                Sharaabi
# 1       politicians do not have permission to do what ...
# 2              I'd like to tell you about one such child,
# 3       This percentage is even greater than the perce...
# 5       what we really mean is that they're bad at not...
# ...                                                   ...
# 273880           National Atmospheric Research Laboratory
# 273881                               Adoor Gopalakrishnan
# 273882                                   Natural language
# 273883                 Unexpected icon chunk in animation
# 273884                   Gorkha National Liberation Front
#
#                                                         4
# 0                                                   शराबी
# 1       राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 2       मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# ...

# %%
df2 = df2.rename({3:'English',4:"Hindi"},axis=1)

# %%
df2
# Out:
#                                                   English  \
# 0                                                Sharaabi
# 1       politicians do not have permission to do what ...
# 2              I'd like to tell you about one such child,
# 3       This percentage is even greater than the perce...
# 4       what we really mean is that they're bad at not...
# ...                                                   ...
# 272748           National Atmospheric Research Laboratory
# 272749                               Adoor Gopalakrishnan
# 272750                                   Natural language
# 272751                 Unexpected icon chunk in animation
# 272752                   Gorkha National Liberation Front
#
#                                                     Hindi
# 0                                                   शराबी
# 1       राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 2       मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# ...

# %%
df2 = df2.reset_index().drop('index',axis=1)

# %%
df2.head()
# Out:
#                                              English  \
# 0                                           Sharaabi
# 1  politicians do not have permission to do what ...
# 2         I'd like to tell you about one such child,
# 3  This percentage is even greater than the perce...
# 4  what we really mean is that they're bad at not...
#
#                                                Hindi
# 0                                              शराबी
# 1  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 2  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 3   यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 4     हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते

# %%
df4 = pd.concat([df2,df3],axis=0)

# %%
df4
# Out:
#                                                  English  \
# 0                                               Sharaabi
# 1      politicians do not have permission to do what ...
# 2             I'd like to tell you about one such child,
# 3      This percentage is even greater than the perce...
# 4      what we really mean is that they're bad at not...
# ...                                                  ...
# 54879  the journey of this salt world popular worldwi...
# 54880  you must have imagined a fairy world of jewels...
# 54881              copernicus popular in had come here\n
# 54882  he was the a student of craco university actua...
# 54883  salt mines administered since th century are s...
#
#                                                    Hindi
# 0                                                  शराबी
# 1      राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 2      मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# ...

# %%
df4.to_csv('raw_data.csv',index=False)

# %%
final_data = pd.read_csv('raw_data.csv',encoding="utf-8")

# %%
final_data.head()
# Out:
#                                              English  \
# 0                                           Sharaabi
# 1  politicians do not have permission to do what ...
# 2         I'd like to tell you about one such child,
# 3  This percentage is even greater than the perce...
# 4  what we really mean is that they're bad at not...
#
#                                                Hindi
# 0                                              शराबी
# 1  राजनीतिज्ञों के पास जो कार्य करना चाहिए, वह कर...
# 2  मई आपको ऐसे ही एक बच्चे के बारे में बताना चाहू...
# 3   यह प्रतिशत भारत में हिन्दुओं प्रतिशत से अधिक है।
# 4     हम ये नहीं कहना चाहते कि वो ध्यान नहीं दे पाते

# %%
final_data.shape
# Out:
# (327637, 2)
